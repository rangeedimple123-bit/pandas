# %%
import numpy as np
import pandas as pd

# %%
marks=[
    [36,87,67,56,45],
    [30,10,40,67,35],
    [25,65,55,34,87],
    [53,23,10,78,68],
    [65,87,98,34,67]
]

# %%
marks_new=pd.DataFrame(marks)
marks_new
# Out:
#     0   1   2   3   4
# 0  36  87  67  56  45
# 1  30  10  40  67  35
# 2  25  65  55  34  87
# 3  53  23  10  78  68
# 4  65  87  98  34  67

# %%
marks_new=pd.DataFrame(marks,columns=['a','b','c','d','e'])
marks_new
# Out:
#     a   b   c   d   e
# 0  36  87  67  56  45
# 1  30  10  40  67  35
# 2  25  65  55  34  87
# 3  53  23  10  78  68
# 4  65  87  98  34  67

# %%
df=pd.read_excel("/store.xls")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df2=pd.read_excel("/store.xls",sheet_name="Returns")
df2
# Out:
#     Returned        Order ID
# 0        Yes  CA-2017-153822
# 1        Yes  CA-2017-129707
# 2        Yes  CA-2014-152345
# 3        Yes  CA-2015-156440
# 4        Yes  US-2017-155999
# ..       ...             ...
# 291      Yes  CA-2015-101910
# 292      Yes  CA-2017-156958
# 293      Yes  CA-2016-105585
# 294      Yes  CA-2016-148796
# 295      Yes  CA-2015-149636
#
# [296 rows x 2 columns]

# %%
df3=pd.read_excel("/store.xls",sheet_name="People")
df3
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 'CA-2016-152156', Timestamp('2016-11-08 00:00:00'), ..., 2,
#         0.0, 41.9136],
#        [2, 'CA-2016-152156', Timestamp('2016-11-08 00:00:00'), ..., 3,
#         0.0, 219.58199999999997],
#        [3, 'CA-2016-138688', Timestamp('2016-06-12 00:00:00'), ..., 2,
#         0.0, 6.8713999999999995],
#        ...,
#        [9992, 'CA-2017-121258', Timestamp('2017-02-26 00:00:00'), ..., 2,
#         0.2, 19.393200000000007],
#        [9993, 'CA-2017-121258', Timestamp('2017-02-26 00:00:00'), ..., 4,
#         0.0, 13.32],
#        [9994, 'CA-2017-119914', Timestamp('2017-05-04 00:00:00'), ..., 2,
#         0.0, 72.94799999999998]], dtype=object)

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df1=df.drop(["Row ID","Order Date","Ship Date","Postal Code"],axis=1)
df1.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'Country', 'City', 'State', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df2=pd.read_excel("/content/Sample - Superstore (16).xls")
df2.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9983 non-null   object
#  2   Order Date     9983 non-null   datetime64[ns]
#  3   Ship Date      9983 non-null   datetime64[ns]
#  4   Ship Mode      9983 non-null   object
#  5   Customer ID    9983 non-null   object
#  6   Customer Name  9983 non-null   object
#  7   Segment        9983 non-null   object
#  8   Country        9974 non-null   object
#  9   City           9974 non-null   object
#  10  State          9956 non-null   object
#  11  Postal Code    9985 non-null   float64
#  12  Region         9985 non-null   object
#  13  Product ID     9976 non-null   object
#  14  Category       9976 non-null   object
#  15  Sub-Category   9976 non-null   object
#  16  Product Name   9976 non-null   object
# ...

# %%
df2.drop(["Segment"],axis=1,inplace=True)
df2
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name        Country             City  \
# 0       CG-12520       Claire Gute  United States        Henderson
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9983 non-null   object
#  2   Order Date     9983 non-null   datetime64[ns]
#  3   Ship Date      9983 non-null   datetime64[ns]
#  4   Ship Mode      9983 non-null   object
#  5   Customer ID    9983 non-null   object
#  6   Customer Name  9983 non-null   object
#  7   Country        9974 non-null   object
#  8   City           9974 non-null   object
#  9   State          9956 non-null   object
#  10  Postal Code    9985 non-null   float64
#  11  Region         9985 non-null   object
#  12  Product ID     9976 non-null   object
#  13  Category       9976 non-null   object
#  14  Sub-Category   9976 non-null   object
#  15  Product Name   9976 non-null   object
#  16  Sales          9950 non-null   float64
# ...

# %%
df2.isnull().sum()
# Out:
# Row ID            0
# Order ID         11
# Order Date       11
# Ship Date        11
# Ship Mode        11
# Customer ID      11
# Customer Name    11
# Country          20
# City             20
# State            38
# Postal Code       9
# Region            9
# Product ID       18
# Category         18
# Sub-Category     18
# Product Name     18
# Sales            44
# Quantity         35
# Discount         26
# Profit           14
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# np.int64(353)

# %%
df2.isna().sum().sum()
# Out:
# np.int64(353)

# %%
df2["Sales"].fillna(df2["Sales"].mean(),inplace=True)
# Out:
# /tmp/ipython-input-509401019.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["Sales"].fillna(df2["Sales"].mean(),inplace=True)

# %%
df2.isnull().sum()
# Out:
# Row ID            0
# Order ID         11
# Order Date       11
# Ship Date        11
# Ship Mode        11
# Customer ID      11
# Customer Name    11
# Country          20
# City             20
# State            38
# Postal Code       9
# Region            9
# Product ID       18
# Category         18
# Sub-Category     18
# Product Name     18
# Sales             0
# Quantity         35
# Discount         26
# Profit           14
# dtype: int64

# %%
df2["City"].fillna(df2["City"].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-2602925570.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["City"].fillna(df2["City"].mode()[0],inplace=True)

# %%
df2.isnull().sum()
# Out:
# Row ID            0
# Order ID         11
# Order Date       11
# Ship Date        11
# Ship Mode        11
# Customer ID      11
# Customer Name    11
# Country          20
# City              0
# State            38
# Postal Code       9
# Region            9
# Product ID       18
# Category         18
# Sub-Category     18
# Product Name     18
# Sales             0
# Quantity         35
# Discount         26
# Profit           14
# dtype: int64

# %%
df2["State"].fillna("New York",inplace=True)
# Out:
# /tmp/ipython-input-3981973638.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["State"].fillna("New York",inplace=True)
